# %% [markdown]
# ## Cleaning Data

# %%
import pandas as pd

# %% [markdown]
# ### President and Congress 1975 through 2010

# %%
# loading url of party control 1933-2010 from southeast missoury state univerity
url_semo = 'http://cstl-cla.semo.edu/rdrenka/ui320-75/presandcongress.asp'
path_2019 = '../Input/party_data.xlsx'

# %%
party_2019 = pd.read_excel(path_2019)

# %%
party_2019
# Out:
#         years  president party_president  house_dem_seats  house_rep_seats  \
# 23    1975-76       Ford               R              291              144
# 24    1977-78     Carter               D              292              143
# 25    1979-80     Carter               D              277              158
# 26    1981-82     Reagan               R              243              192
# 27    1983-84     Reagan               R              269              166
# 28    1985-86     Reagan               R              253              182
# 29    1987-88     Reagan               R              258              177
# 30    1989-90  Bush, GHW               R              260              175
# 31    1991-92       Bush               R              267              167
# 32    1993-94    Clinton               D              258              176
# 33    1995-96    Clinton               D              202              232
# 34    1997-98    Clinton               D              206              228
# 35  1999-2000    Clinton               D              211              223
# 36    2001-02   Bush, GW               R              212              221
# 37    2003-04   Bush, GW               R              204              228
# 38    2005-06   Bush, GW               R              200              234
# 39    2007-08   Bush, GW               R              231              204
# 40    2009-10      Obama               D              257              178
#
#     house_other_seats  senate_dem_seats  senate_rep_seats  senate_other_seats  \
# 23                  0                61                38                   1
# 24                  0                62                38                   0
# 25                  0                59                41                   0
# 26                  0                47                53                   0
# 27                  0                46                54                   0
# 28                  0                47                53                   0
# 29                  0                55                45                   0
# 30                  0                55                45                   0
# 31                  1                56                44                   0
# 32                  1                57                43                   0
# 33                  1                46                54                   0
# 34                  1                45                55                   0
# 35                  1                45                55                   0
# 36                  2                50                49                   1
# 37                  3                48                51                   1
# 38                  1                45                55                   0
# 39                  0                51                49                   0
# 40                  0                60                40                   0
#
#       gov_status  term_start  term_end
# 23       divided        1975      1976
# 24       unified        1977      1978
# 25       unified        1979      1980
# 26  divided (HR)        1981      1982
# 27  divided (HR)        1983      1984
# 28  divided (HR)        1985      1986
# 29       divided        1987      1988
# 30       divided        1989      1990
# 31       divided        1991      1992
# 32       unified        1993      1994
# 33       divided        1995      1996
# 34       divided        1997      1998
# 35       divided        1999      1920
# 36       divided        2001      2002
# 37       unified        2003      2004
# 38       unified        2005      2006
# 39       divided        2007      2008
# 40       unified        2009      2010

# %%
# Creating a dataframe 
list_semo = pd.read_html(url_semo)

# DataFrame
df = list_semo[0]

# %%
list_del = [0,1,41,42]

# %%
# Create a list of range 2 to 22 inclusive 
list_range = list(range(2,23))

# %%
# extend first list to the range list
list_del.extend(list_range)

# %%
# drop the indices in our dataframe using list_del list 
party_shutdown_df = df.drop(df.index[list_del])

# %%
party_with_headers = party_shutdown_df.rename(columns={
    0:"years",1:"president",2:"party_president",4:"house_dem_seats",5:"house_rep_seats",6:"house_other_seats",
    7:"senate_dem_seats",8:"senate_rep_seats",9:"senate_other_seats",10:"gov_status"
})

# delete column with header '3'
del party_with_headers[3]

# %%
# resetting dataframe index 
party_with_headers.reset_index(drop=True).head(3)
# Out:
#      years president party_president house_dem_seats house_rep_seats  \
# 0  1975-76      Ford               R             291             144
# 1  1977-78    Carter               D             292             143
# 2  1979-80    Carter               D             277             158
#
#   house_other_seats  senate_dem_seats senate_rep_seats  senate_other_seats  \
# 0                 0              61.0               38                 1.0
# 1                 0              62.0               38                 0.0
# 2                 0              59.0               41                 0.0
#
#   gov_status
# 0    divided
# 1    unified
# 2    unified

# %%
# checking if there is any NaN value left in the dataframe 
party_with_headers.isnull().values.any()
# Out:
# False

# %%
# looking up types of columns in the dataframe
party_with_headers.dtypes
# Out:
# years                  object
# president              object
# party_president        object
# house_dem_seats        object
# house_rep_seats        object
# house_other_seats      object
# senate_dem_seats      float64
# senate_rep_seats       object
# senate_other_seats    float64
# gov_status             object
# dtype: object

# %%
# create a copy of dataframe to change types
party_df_types = party_with_headers

# %%
# Converting three series to numerics
party_df_types['house_dem_seats'] = pd.to_numeric(party_df_types['house_dem_seats'])
party_df_types['house_rep_seats'] = pd.to_numeric(party_df_types['house_rep_seats'])
party_df_types['house_other_seats'] = pd.to_numeric(party_df_types['house_other_seats'])

# %%
party_df_types.dtypes
# Out:
# years                  object
# president              object
# party_president        object
# house_dem_seats         int64
# house_rep_seats         int64
# house_other_seats       int64
# senate_dem_seats      float64
# senate_rep_seats       object
# senate_other_seats    float64
# gov_status             object
# dtype: object

# %%
# Appending of the two dataframes 
party_complete = party_df_types.append(party_2019)
# Out:
# /Users/ahmedacheikh/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:6201: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   sort=sort)

# %%
party_complete.reset_index(drop=True).head()
# Out:
#      gov_status  house_dem_seats  house_other_seats  house_rep_seats  \
# 0       divided              291                  0              144
# 1       unified              292                  0              143
# 2       unified              277                  0              158
# 3  divided (HR)              243                  0              192
# 4  divided (HR)              269                  0              166
#
#   party_president president  senate_dem_seats  senate_other_seats  \
# 0               R      Ford              61.0                 1.0
# 1               D    Carter              62.0                 0.0
# 2               D    Carter              59.0                 0.0
# 3               R    Reagan              47.0                 0.0
# 4               R    Reagan              46.0                 0.0
#
#   senate_rep_seats  term_end  term_start    years
# 0               38       NaN         NaN  1975-76
# 1               38       NaN         NaN  1977-78
# 2               41       NaN         NaN  1979-80
# 3               53       NaN         NaN  1981-82
# 4               54       NaN         NaN  1983-84

# %% [markdown]
# ##### 'senate_rep_seats' cannot be changed to float or int yet because of the value '49*'

# %%
# using .loc to locate the "49*" value and changing it to '49'
party_df_types['senate_rep_seats'].loc[party_df_types['senate_rep_seats'] == "49*"] = '49'
# Out:
# /Users/ahmedacheikh/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
party_df_types['senate_rep_seats'] = pd.to_numeric(party_df_types['senate_rep_seats'])

# %%
party_df_types.dtypes
# Out:
# years                  object
# president              object
# party_president        object
# house_dem_seats         int64
# house_rep_seats         int64
# house_other_seats       int64
# senate_dem_seats      float64
# senate_rep_seats        int64
# senate_other_seats    float64
# gov_status             object
# dtype: object

# %%
# resetting index again just because anaconda is confused
party_df_types.reset_index(drop=True).head(3)
# Out:
#      years president party_president  house_dem_seats  house_rep_seats  \
# 0  1975-76      Ford               R              291              144
# 1  1977-78    Carter               D              292              143
# 2  1979-80    Carter               D              277              158
#
#    house_other_seats  senate_dem_seats  senate_rep_seats  senate_other_seats  \
# 0                  0              61.0                38                 1.0
# 1                  0              62.0                38                 0.0
# 2                  0              59.0                41                 0.0
#
#   gov_status
# 0    divided
# 1    unified
# 2    unified

# %%
party_df_types["term_start"] = party_df_types["years"].str.slice(0,4,1)
party_df_types

party_df_types["term_end"] = party_df_types["years"].str.slice(0,2,1) + party_df_types["years"].str.slice(5,7,1)
party_df_types.head(3)
# Out:
#       years president party_president  house_dem_seats  house_rep_seats  \
# 23  1975-76      Ford               R              291              144
# 24  1977-78    Carter               D              292              143
# 25  1979-80    Carter               D              277              158
#
#     house_other_seats  senate_dem_seats  senate_rep_seats  senate_other_seats  \
# 23                  0              61.0                38                 1.0
# 24                  0              62.0                38                 0.0
# 25                  0              59.0                41                 0.0
#
#    gov_status term_start term_end
# 23    divided       1975     1976
# 24    unified       1977     1978
# 25    unified       1979     1980

# %%
# Saving to Excel file
writer = pd.ExcelWriter('output.xlsx')
party_complete.to_excel(writer, index=False,header=True)
writer.save()

# %% [markdown]
# ### Cleaning President Trump Approval Ratings

# %%
# url for President Trump approval ratings 
url_trump_gallup = "https://news.gallup.com/poll/203198/presidential-approval-ratings-donald-trump.aspx"

# %%
# Read the url
list_trump_gallup = pd.read_html(url_trump_gallup)

# %%
# save the section in dataframe to clean 
trump_not_clean = list_trump_gallup[2]
list_trump_del = [0,2,102,104]

# %%
trump_not_clean.head()
# Out:
#   Unnamed: 0_level_0 Approve Disapprove No opinion
#   Unnamed: 0_level_1       %          %          %
# 0               2019     NaN        NaN        NaN
# 1      2019 Jan 2-10      37         59          4
# 2               2018     NaN        NaN        NaN
# 3     2018 Dec 17-22      39         55          5
# 4     2018 Dec 10-16      38         57          4

# %%
# getting rid of second row and last
trump_clean = trump_not_clean.drop(trump_not_clean.index[list_trump_del])

# %%
trump_clean.head()
# Out:
#   Unnamed: 0_level_0 Approve Disapprove No opinion
#   Unnamed: 0_level_1       %          %          %
# 1      2019 Jan 2-10      37         59          4
# 3     2018 Dec 17-22      39         55          5
# 4     2018 Dec 10-16      38         57          4
# 5       2018 Dec 3-9      40         56          4
# 6  2018 Nov 26-Dec 2      40         56          4

# %%
trump_clean.tail()
# Out:
#     Unnamed: 0_level_0 Approve Disapprove No opinion
#     Unnamed: 0_level_1       %          %          %
# 98   2017 Feb 27-Mar 5      43         51          6
# 99      2017 Feb 20-26      42         53          5
# 100     2017 Feb 13-19      40         54          5
# 101      2017 Feb 6-12      41         53          6
# 103     2017 Jan 20-29      45         47          8

# %%
trump_clean.reset_index(drop=True).head(3)
# Out:
#   Unnamed: 0_level_0 Approve Disapprove No opinion
#   Unnamed: 0_level_1       %          %          %
# 0      2019 Jan 2-10      37         59          4
# 1     2018 Dec 17-22      39         55          5
# 2     2018 Dec 10-16      38         57          4

# %%
# drop one level of the multi index column headers
trump_clean.columns = trump_clean.columns.droplevel()

# %%
# Column names
trump_clean.columns
# Out:
# Index(['Unnamed: 0_level_1', '%', '%', '%'], dtype='object')

# %%
trump_clean.head(2)
# Out:
#   Unnamed: 0_level_1   %   %  %
# 1      2019 Jan 2-10  37  59  4
# 3     2018 Dec 17-22  39  55  5

# %%
# Renaming column headers
trump_cleaner = trump_clean.rename(columns={
    'Unnamed: 0_level_1': 'weekly', '%':'approve','%':'disapprove','%':'no_opinion'
})

trump_cleaner.reset_index(drop=True).head(3)
# Out:
#            weekly no_opinion no_opinion no_opinion
# 0   2019 Jan 2-10         37         59          4
# 1  2018 Dec 17-22         39         55          5
# 2  2018 Dec 10-16         38         57          4

# %%
# setting column names by index
trump_cleaner.columns.values[1] = 'approve_trump'
trump_cleaner.columns.values[2] = 'disapprove_trump'
trump_cleaner.columns.values[3] = 'no_opinion_trump'

# %%
# numerizing approval ratings' columns
trump_cleaner['approve_trump'] = pd.to_numeric(trump_cleaner['approve_trump'])
trump_cleaner['disapprove_trump'] = pd.to_numeric(trump_cleaner['disapprove_trump'])
trump_cleaner['no_opinion_trump'] = pd.to_numeric(trump_cleaner['no_opinion_trump'])

# %%
trump_clean = pd.DataFrame()
trump_cleanest = trump_cleaner

trump_cleanest.tail(3)
# Out:
#              weekly  approve_trump  disapprove_trump  no_opinion_trump
# 100  2017 Feb 13-19           40.0              54.0               5.0
# 101   2017 Feb 6-12           41.0              53.0               6.0
# 103  2017 Jan 20-29           45.0              47.0               8.0

# %%
trump_cleanest.head(3)
# Out:
#            weekly  approve_trump  disapprove_trump  no_opinion_trump
# 1   2019 Jan 2-10           37.0              59.0               4.0
# 3  2018 Dec 17-22           39.0              55.0               5.0
# 4  2018 Dec 10-16           38.0              57.0               4.0

# %% [markdown]
# ##### Getting rid of NaNs

# %%
trump_cleanest.isnull().any()
# Out:
# weekly              False
# approve_trump        True
# disapprove_trump     True
# no_opinion_trump     True
# dtype: bool

# %%
null_columns_trump = trump_cleanest.columns[trump_cleanest.isnull().any()]
trump_cleanest[null_columns_trump].isnull().sum()
# Out:
# approve_trump       1
# disapprove_trump    1
# no_opinion_trump    1
# dtype: int64

# %%
trump_cleanest[trump_cleanest['approve_trump'].isnull()][null_columns_trump]
# Out:
#     approve_trump  disapprove_trump  no_opinion_trump
# 54            NaN               NaN               NaN

# %%
trump_new = trump_cleanest.dropna()

# %%
trump_new.reset_index(drop=True).head(3)
# Out:
#            weekly  approve_trump  disapprove_trump  no_opinion_trump
# 0   2019 Jan 2-10           37.0              59.0               4.0
# 1  2018 Dec 17-22           39.0              55.0               5.0
# 2  2018 Dec 10-16           38.0              57.0               4.0

# %%
trump_new.isnull().any().sum()
# Out:
# 0

# %%
trump_new[50:53]
# Out:
#             weekly  approve_trump  disapprove_trump  no_opinion_trump
# 52   2018 Jan 8-14           38.0              57.0               5.0
# 53    2018 Jan 1-7           37.0              58.0               4.0
# 55  2017 Dec 25-31           39.0              55.0               6.0

# %%
tc = trump_new.copy()
tc.head()

# Separate the dates in the weekly column into a Start Date & End Date column

# Separate into usable pieces
yr = tc['weekly'].str.slice(0,4,1)
mo = tc['weekly'].str.slice(5,8,1)
lo = tc['weekly'].str.slice(9,17,1)
rs = lo.str.split('-')
rs1 = rs.str.get(0)
rs2 = rs.str.get(1)
rs3 = rs2.str.split(' ')
rs4 = rs3.str.get(0)
rs5 = rs3.str.get(1)

# Build the Start Date (sd)
tc['sd'] = mo + " " + rs1 + " " + yr

# Build the End Date (ed)
nulls = rs5.isnull()
nulls
for x in nulls:
    if x == True:
        tc['ed'] = mo + " " + rs2 + " " + yr
    else:
        tc['ed'] = rs4 + " " + rs5 + " " + yr
tc[51:105]
        
# # Create a new copy
tc2 = tc.copy()
tc2.head()

# # Fix rows that have a duplicated month in the end date column
tc2.ed[4] = tc2.ed[4][4:]
tc2.ed[8] = tc2.ed[8][4:]
tc2.ed[17] = tc2.ed[17][4:]
tc2.ed[21] = tc2.ed[21][4:]
tc2.ed[26] = tc2.ed[26][4:]
tc2.ed[30] = tc2.ed[30][4:]
tc2.ed[34] = tc2.ed[34][4:]
tc2.ed[39] = tc2.ed[39][4:]
tc2.ed[43] = tc2.ed[43][4:]
tc2.ed[47] = tc2.ed[47][4:]
tc2.ed[57] = tc2.ed[57][4:]
tc2.ed[61] = tc2.ed[61][4:]
tc2.ed[66] = tc2.ed[66][4:]
tc2.ed[70] = tc2.ed[70][4:]
tc2.ed[74] = tc2.ed[74][4:]
tc2.ed[79] = tc2.ed[79][4:]
tc2.ed[83] = tc2.ed[83][4:]
tc2.ed[92] = tc2.ed[92][4:]
tc2.ed[96] = tc2.ed[96][4:]
tc2.ed[100] = tc2.ed[100][4:]
# Out:
# /Users/ahmedacheikh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/ahmedacheikh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/ahmedacheikh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/ahmedacheikh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/ahmedacheikh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/ahmedacheikh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/ahmedacheikh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/ahmedacheikh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/ahmedacheikh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/ahmedacheikh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/ahmedacheikh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/ahmedacheikh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/ahmedacheikh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/ahmedacheikh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/ahmedacheikh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/ahmedacheikh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/ahmedacheikh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/ahmedacheikh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/ahmedacheikh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/ahmedacheikh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
tc2
# Out:
#                 weekly  approve_trump  disapprove_trump  no_opinion_trump  \
# 1        2019 Jan 2-10           37.0              59.0               4.0
# 3       2018 Dec 17-22           39.0              55.0               5.0
# 4       2018 Dec 10-16           38.0              57.0               4.0
# 5         2018 Dec 3-9           40.0              56.0               4.0
# 6    2018 Nov 26-Dec 2           40.0              56.0               4.0
# 7       2018 Nov 19-25           38.0              60.0               3.0
# 8       2018 Nov 12-18           43.0              53.0               4.0
# 9        2018 Nov 5-11           38.0              56.0               5.0
# 10   2018 Oct 29-Nov 4           40.0              54.0               6.0
# 11      2018 Oct 22-28           40.0              54.0               6.0
# 12      2018 Oct 15-21           44.0              50.0               6.0
# 13       2018 Oct 8-14           44.0              51.0               5.0
# 14        2018 Oct 1-7           43.0              53.0               5.0
# 15      2018 Sep 24-30           42.0              53.0               5.0
# 16      2018 Sep 17-23           40.0              56.0               5.0
# 17      2018 Sep 10-16           38.0              56.0               6.0
# 18        2018 Sep 3-9           40.0              54.0               5.0
# 19   2018 Aug 27-Sep 2           41.0              53.0               6.0
# 20      2018 Aug 20-26           41.0              54.0               5.0
# 21      2018 Aug 13-19           42.0              52.0               7.0
# 22       2018 Aug 6-12           39.0              56.0               5.0
# 23   2018 Jul 30-Aug 5           41.0              54.0               5.0
# 24      2018 Jul 23-29           40.0              55.0               6.0
# 25      2018 Jul 16-22           42.0              54.0               4.0
# 26       2018 Jul 9-15           43.0              52.0               4.0
# 27        2018 Jul 2-8           41.0              56.0               4.0
# 28   2018 Jun 25-Jul 1           42.0              53.0               5.0
# 29      2018 Jun 18-24           41.0              55.0               3.0
# 30      2018 Jun 11-17           45.0              50.0               4.0
# 31       2018 Jun 4-10           42.0              54.0               4.0
# ..                 ...            ...               ...               ...
# 73      2017 Aug 21-27           35.0              60.0               5.0
# 74      2017 Aug 14-20           37.0              58.0               6.0
# 75       2017 Aug 7-13           36.0              58.0               6.0
# 76   2017 Jul 31-Aug 6           37.0              58.0               5.0
# 77      2017 Jul 24-30           38.0              57.0               5.0
# 78      2017 Jul 17-23           37.0              58.0               5.0
# 79      2017 Jul 10-16           39.0              56.0               6.0
# 80        2017 Jul 3-9           38.0              57.0               5.0
# 81   2017 Jun 26-Jul 2           39.0              56.0               5.0
# 82      2017 Jun 19-25           39.0              56.0               5.0
# 83      2017 Jun 12-18           38.0              57.0               6.0
# 84       2017 Jun 5-11           37.0              58.0               5.0
# 85   2017 May 29-Jun 4           38.0              56.0               6.0
# 86      2017 May 22-28           41.0              54.0               5.0
# 87      2017 May 15-21           38.0              56.0               6.0
# 88       2017 May 8-14           38.0              56.0               6.0
# 89        2017 May 1-7           42.0              53.0               6.0
# 90      2017 Apr 24-30           41.0              54.0               5.0
# 91      2017 Apr 17-23           41.0              52.0               7.0
# 92      2017 Apr 10-16           40.0              54.0               6.0
# 93        2017 Apr 3-9           40.0              53.0               7.0
# 94   2017 Mar 27-Apr 2           38.0              57.0               5.0
# 95      2017 Mar 20-26           39.0              56.0               6.0
# 96      2017 Mar 13-19           40.0              55.0               5.0
# 97       2017 Mar 6-12           42.0              52.0               6.0
# 98   2017 Feb 27-Mar 5           43.0              51.0               6.0
# 99      2017 Feb 20-26           42.0              53.0               5.0
# 100     2017 Feb 13-19           40.0              54.0               5.0
# 101      2017 Feb 6-12           41.0              53.0               6.0
# 103     2017 Jan 20-29           45.0              47.0               8.0
#
#               sd              ed
# 1     Jan 2 2019     Jan 10 2019
# 3    Dec 17 2018     Dec 22 2018
# 4    Dec 10 2018         16 2018
# 5     Dec 3 2018      Dec 9 2018
# 6    Nov 26 2018  Nov Dec 2 2018
# 7    Nov 19 2018     Nov 25 2018
# 8    Nov 12 2018         18 2018
# 9     Nov 5 2018     Nov 11 2018
# 10   Oct 29 2018  Oct Nov 4 2018
# 11   Oct 22 2018     Oct 28 2018
# 12   Oct 15 2018     Oct 21 2018
# 13    Oct 8 2018     Oct 14 2018
# 14    Oct 1 2018      Oct 7 2018
# 15   Sep 24 2018     Sep 30 2018
# 16   Sep 17 2018     Sep 23 2018
# 17   Sep 10 2018         16 2018
# 18    Sep 3 2018      Sep 9 2018
# 19   Aug 27 2018  Aug Sep 2 2018
# 20   Aug 20 2018     Aug 26 2018
# 21   Aug 13 2018         19 2018
# 22    Aug 6 2018     Aug 12 2018
# 23   Jul 30 2018  Jul Aug 5 2018
# 24   Jul 23 2018     Jul 29 2018
# 25   Jul 16 2018     Jul 22 2018
# 26    Jul 9 2018         15 2018
# 27    Jul 2 2018      Jul 8 2018
# 28   Jun 25 2018  Jun Jul 1 2018
# 29   Jun 18 2018     Jun 24 2018
# 30   Jun 11 2018         17 2018
# 31    Jun 4 2018     Jun 10 2018
# ..           ...             ...
# 73   Aug 21 2017     Aug 27 2017
# 74   Aug 14 2017         20 2017
# 75    Aug 7 2017     Aug 13 2017
# 76   Jul 31 2017  Jul Aug 6 2017
# 77   Jul 24 2017     Jul 30 2017
# 78   Jul 17 2017     Jul 23 2017
# 79   Jul 10 2017         16 2017
# 80    Jul 3 2017      Jul 9 2017
# 81   Jun 26 2017  Jun Jul 2 2017
# 82   Jun 19 2017     Jun 25 2017
# 83   Jun 12 2017         18 2017
# 84    Jun 5 2017     Jun 11 2017
# 85   May 29 2017  May Jun 4 2017
# 86   May 22 2017     May 28 2017
# 87   May 15 2017     May 21 2017
# 88    May 8 2017     May 14 2017
# 89    May 1 2017      May 7 2017
# 90   Apr 24 2017     Apr 30 2017
# 91   Apr 17 2017     Apr 23 2017
# 92   Apr 10 2017         16 2017
# 93    Apr 3 2017      Apr 9 2017
# 94   Mar 27 2017  Mar Apr 2 2017
# 95   Mar 20 2017     Mar 26 2017
# 96   Mar 13 2017         19 2017
# 97    Mar 6 2017     Mar 12 2017
# 98   Feb 27 2017  Feb Mar 5 2017
# 99   Feb 20 2017     Feb 26 2017
# 100  Feb 13 2017         19 2017
# 101   Feb 6 2017     Feb 12 2017
# 103  Jan 20 2017     Jan 29 2017
#
# [100 rows x 6 columns]

# %% [markdown]
# ### Cleaning Presidents Obama, Bush, Clinton, Bush Sen., Reagan, Carter, and Ford ratings

# %%
# Getting presidential approval ratings dating back to President Ford except Trump. (not up to date for trump) 
# 'https://www.presidency.ucsb.edu/statistics/data/presidential-job-approval'

# %%
# load presidential approval data paths 
obama_path = '../../obama.csv'
bush_path = '../../bush.csv'
clinton_path = '../../clinton.csv'
bush_senior_path = '../../bush_senior.csv'
reagan_path = '../../reagan.csv'
carter_path = '../../carter.csv'
ford_path = '../../ford.csv'

# %%
# save them into dataframes 
obama_df = pd.read_csv(obama_path)
bush_df = pd.read_csv(bush_path)
clinton_df = pd.read_csv(clinton_path)
bush_senior_df = pd.read_csv(bush_senior_path)
reagan_df = pd.read_csv(reagan_path)
carter_df = pd.read_csv(carter_path)
ford_df = pd.read_csv(ford_path)

# %%
bush_df.dtypes
# Out:
# Start Date       object
# End Date         object
# Approving         int64
# Disapproving      int64
# Unsure/NoData     int64
# dtype: object

# %%
# Change 'Start Date' & 'End Date' columns to datetime types 
obama_df['Start Date'] = pd.to_datetime(obama_df['Start Date'])
obama_df['End Date'] = pd.to_datetime(obama_df['End Date'])

bush_df['Start Date'] = pd.to_datetime(bush_df['Start Date'])
bush_df['End Date'] = pd.to_datetime(bush_df['End Date'])

clinton_df['Start Date'] = pd.to_datetime(clinton_df['Start Date'])
clinton_df['End Date'] = pd.to_datetime(clinton_df['End Date'])

bush_senior_df['Start Date'] = pd.to_datetime(bush_senior_df['Start Date'])
bush_senior_df['End Date'] = pd.to_datetime(bush_senior_df['End Date'])

reagan_df['Start Date'] = pd.to_datetime(reagan_df['Start Date'])
reagan_df['End Date'] = pd.to_datetime(reagan_df['End Date'])

carter_df['Start Date'] = pd.to_datetime(carter_df['Start Date'])
carter_df['End Date'] = pd.to_datetime(carter_df['End Date'])

ford_df['Start Date'] = pd.to_datetime(ford_df['Start Date'])
ford_df['End Date'] = pd.to_datetime(ford_df['End Date'])

# %%
# Change headers to where they don't have space
obama_df = obama_df.rename(columns={
                           'Start Date':'start_date_obama',
                           'End Date':'end_date_obama',
                           'Approving':'approve_obama',
                           'Disapproving':'dissaprove_obama',
                           'Unsure/NoData':'unsure_obama'
})

bush_df = bush_df.rename(columns={
                           'Start Date':'start_date_bush',
                           'End Date':'end_date_bush',
                           'Approving':'approve_bush',
                           'Disapproving':'dissaprove_bush',
                           'Unsure/NoData':'unsure_bush'
})

clinton_df = clinton_df.rename(columns={
                           'Start Date':'start_date_clinton',
                           'End Date':'end_date_clinton',
                           'Approving':'approve_clinton',
                           'Disapproving':'dissaprove_clinton',
                           'Unsure/NoData':'unsure_clinton'
})

bush_senior_df = bush_senior_df.rename(columns={
                           'Start Date':'start_date_bush_senior',
                           'End Date':'end_date_bush_senior',
                           'Approving':'approve_bush_senior',
                           'Disapproving':'dissaprove_bush_senior',
                           'Unsure/NoData':'unsure_bush_senior'
})

reagan_df = reagan_df.rename(columns={
                           'Start Date':'start_date_reagan',
                           'End Date':'end_date_reagan',
                           'Approving':'approve_reagan',
                           'Disapproving':'dissaprove_reagan',
                           'Unsure/NoData':'unsure_reagan'
})

carter_df = carter_df.rename(columns={
                           'Start Date':'start_date_carter',
                           'End Date':'end_date_carter',
                           'Approving':'approve_carter',
                           'Disapproving':'dissaprove_carter',
                           'Unsure/NoData':'unsure_carter'
})

ford_df = ford_df.rename(columns={
                           'Start Date':'start_date_ford',
                           'End Date':'end_date_ford',
                           'Approving':'approve_ford',
                           'Disapproving':'dissaprove_ford',
                           'Unsure/NoData':'unsure_ford'
})

# %%
# check for null values in former Presidents' dataframes
print(obama_df.isnull().any())
print('----'*15)

print(bush_df.isnull().any())
print('----'*15)

print(clinton_df.isnull().any())
print('----'*15)

print(bush_senior_df.isnull().any())
print('----'*15)

print(reagan_df.isnull().any())
print('----'*15)

print(carter_df.isnull().any())
print('----'*15)

print(ford_df.isnull().any())
print('----'*15)
# Out:
# start_date_obama    False
# end_date_obama      False
# approve_obama       False
# dissaprove_obama    False
# unsure_obama        False
# dtype: bool
# ------------------------------------------------------------
# start_date_bush    False
# end_date_bush      False
# approve_bush       False
# dissaprove_bush    False
# unsure_bush        False
# dtype: bool
# ------------------------------------------------------------
# start_date_clinton    False
# end_date_clinton      False
# approve_clinton       False
# dissaprove_clinton    False
# unsure_clinton        False
# dtype: bool
# ------------------------------------------------------------
# start_date_bush_senior    False
# end_date_bush_senior      False
# approve_bush_senior       False
# dissaprove_bush_senior    False
# unsure_bush_senior        False
# dtype: bool
# ------------------------------------------------------------
# start_date_reagan    False
# end_date_reagan      False
# approve_reagan       False
# dissaprove_reagan    False
# unsure_reagan        False
# dtype: bool
# ------------------------------------------------------------
# start_date_carter    False
# end_date_carter      False
# approve_carter       False
# dissaprove_carter    False
# unsure_carter        False
# dtype: bool
# ------------------------------------------------------------
# start_date_ford    False
# end_date_ford      False
# approve_ford       False
# dissaprove_ford    False
# unsure_ford        False
# dtype: bool
# ------------------------------------------------------------

# %% [markdown]
# ### Congress Approval Cleaning

# %%
# url for congress approval ratings
url_congr = 'https://news.gallup.com/poll/1600/congress-public.aspx'

# %%
# loading and saving congress' approval ratings into a dataframe 
list_congr = pd.read_html(url_congr)
congress_df = list_congr[0]

# %%
congress_df.head(2)
# Out:
#   Unnamed: 0_level_0 Approve Disapprove No opinion Unnamed: 4_level_0  \
#   Unnamed: 0_level_1       %          %          % Unnamed: 4_level_1
# 0      2018 Dec 3-12      18         75          7                NaN
# 1      2018 Nov 1-11      21         74          5                NaN
#
#   Unnamed: 5_level_0 Unnamed: 6_level_0 Unnamed: 7_level_0 Unnamed: 8_level_0  \
#   Unnamed: 5_level_1 Unnamed: 6_level_1 Unnamed: 7_level_1 Unnamed: 8_level_1
# 0                NaN                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
#
#   Unnamed: 9_level_0         ...         Unnamed: 33_level_0  \
#   Unnamed: 9_level_1         ...         Unnamed: 33_level_1
# 0                NaN         ...                         NaN
# 1                NaN         ...                         NaN
#
#   Unnamed: 34_level_0 Unnamed: 35_level_0 Unnamed: 36_level_0  \
#   Unnamed: 34_level_1 Unnamed: 35_level_1 Unnamed: 36_level_1
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   Unnamed: 37_level_0 Unnamed: 38_level_0 Unnamed: 39_level_0  \
#   Unnamed: 37_level_1 Unnamed: 38_level_1 Unnamed: 39_level_1
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
#   Unnamed: 40_level_0 Unnamed: 41_level_0 Unnamed: 42_level_0
#   Unnamed: 40_level_1 Unnamed: 41_level_1 Unnamed: 42_level_1
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
#
# [2 rows x 43 columns]

# %%
# Drop a level from headers
congress_df.columns = congress_df.columns.droplevel()

# %%
# printing the length of columns array
len(congress_df.columns.values)
# Out:
# 43

# %%
congress_df = congress_df.drop(congress_df.index[333])

# %%
# dropping some columns
congress_cleaning = congress_df[['Unnamed: 0_level_1','%']]

# %%
congress_clean = congress_cleaning.rename(columns={
    'Unnamed: 0_level_1':'weekly','%':'approve','%':'disapprove','%':'no_opinion_congress'
})

# %%
# print last five rows
congress_clean.head(3)
# Out:
#            weekly no_opinion_congress no_opinion_congress no_opinion_congress
# 0   2018 Dec 3-12                  18                  75                   7
# 1   2018 Nov 1-11                  21                  74                   5
# 2  2018 Oct 15-28                  21                  74                   6

# %%
# check for null values
congress_clean.isnull().any()
# Out:
# weekly                 False
# no_opinion_congress    False
# no_opinion_congress    False
# no_opinion_congress    False
# dtype: bool

# %% [markdown]
# ##### Trying to rename by index

# %%
# changing column names by index
congress_clean.columns.values[1] = 'approve_congress'
congress_clean.columns.values[2] = 'disapprove_congress'

# %%
# check types
congress_clean.dtypes
# Out:
# weekly                 object
# approve_congress       object
# disapprove_congress    object
# no_opinion_congress    object
# dtype: object

# %%
# Setting approve, disapprove and no_opinion columns to numeric types
congress_clean['approve_congress'] = pd.to_numeric(congress_clean['approve_congress'])
congress_clean['disapprove_congress'] = pd.to_numeric(congress_clean['disapprove_congress'])
congress_clean['no_opinion_congress'] = pd.to_numeric(congress_clean['no_opinion_congress'])

# %%
congress_clean.head(3)
# Out:
#            weekly  approve_congress  disapprove_congress  no_opinion_congress
# 0   2018 Dec 3-12                18                   75                    7
# 1   2018 Nov 1-11                21                   74                    5
# 2  2018 Oct 15-28                21                   74                    6

# %% [markdown]
# ##### This part will deal with slicing 'weekly' column

# %%
cc = congress_clean.copy()

# Separate the dates in the weekly column into a Start Date & End Date column

# Separate into usable pieces
yr = cc['weekly'].str.slice(0,4,1)
mo = cc['weekly'].str.slice(5,8,1)
lo = cc['weekly'].str.slice(9,17,1)
rs = lo.str.split('-')
rs1 = rs.str.get(0)
rs2 = rs.str.get(1)
rs3 = rs2.str.split(' ')
rs4 = rs3.str.get(0)
rs5 = rs3.str.get(1)

# Build the Start Date (sd)
cc['sd'] = mo + " " + rs1 + " " + yr

# Build the End Date (ed)
nulls = rs5.isnull()
nulls
for x in nulls:
    if x == True:
        cc['ed'] = mo + " " + rs2 + " " + yr
    else:
        cc['ed'] = rs4 + " " + rs5 + " " + yr

# Create a new copy
cc2 = cc.copy()
cc2.head()


# Drop row 304 -- 304 1992 Mar 3 ^ 18 78 3 Mar 3 ^ 1992 NaN
cc3 = cc2.drop([304], axis=0)
cc3


# Reset the index after the deletion of row 304
cc4 = cc3.reset_index(drop=True)
cc4


cc5 = cc4.copy()

# Fix 10 rows that have a duplicated month in the end date column
cc5.ed[51] = cc5.ed[51][4:]
cc5.ed[114] = cc5.ed[114][4:]
cc5.ed[251] = cc5.ed[251][4:]
cc5.ed[262] = cc5.ed[262][4:]
cc5.ed[269] = cc5.ed[269][4:]
cc5.ed[278] = cc5.ed[278][4:]
cc5.ed[311] = cc5.ed[311][4:]
cc5.ed[313] = cc5.ed[313][4:]
cc5.ed[325] = cc5.ed[325][4:]
cc5.ed[328] = cc5.ed[328][4:]
# Out:
# /Users/ahmedacheikh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/ahmedacheikh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/ahmedacheikh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/ahmedacheikh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/ahmedacheikh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/ahmedacheikh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/ahmedacheikh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/ahmedacheikh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/ahmedacheikh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/ahmedacheikh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
cc5.sd = pd.to_datetime(cc5.sd)
cc5.ed = pd.to_datetime(cc5.ed)

# %%
cc5.tail()
# Out:
#                 weekly  approve_congress  disapprove_congress  \
# 327     1975 Apr 18-21                38                   48
# 328  1975 Feb 28-Mar 3                32                   50
# 329     1974 Oct 11-14                35                   43
# 330     1974 Aug 16-19                47                   34
# 331     1974 Apr 12-15                30                   47
#
#      no_opinion_congress         sd         ed
# 327                   14 1975-04-18 1975-04-21
# 328                   18 1975-02-28 1975-03-03
# 329                   22 1974-10-11 1974-10-14
# 330                   19 1974-08-16 1974-08-19
# 331                   23 1974-04-12 1974-04-15

# %%
cc5.dtypes
# Out:
# weekly                         object
# approve_congress                int64
# disapprove_congress             int64
# no_opinion_congress             int64
# sd                     datetime64[ns]
# ed                     datetime64[ns]
# dtype: object

# %%
writer = pd.ExcelWriter('congress_approval.xlsx')
cc5.to_excel(writer, index=False,header=True)
writer.save()

# %% [markdown]
# ### Cleaning Unemployment Rate Data

# %%
# Federal Reserve Bank of St. Louis (Monthly Unemployment rate)
url_unemp = 'http://www.multpl.com/unemployment/table?f=m'

# %%
# loading data
list_unemp = pd.read_html(url_unemp)

# %%
# saving into a dataframe 
unemp_df = list_unemp[0]

# %%
# Look up
unemp_df.head(3)
# Out:
#              0           1
# 0         Date  Rate Value
# 1  Dec 1, 2018       3.90%
# 2  Nov 1, 2018       3.70%

# %%
# Rename headers
unemp_df = unemp_df.rename(columns={
    0:'date_unemp',1:'unemp_rate'
})

# %%
# Drop first row
unemp_clean = unemp_df.drop(unemp_df.index[0])

# %%
# Reset index
unemp_clean.reset_index(drop=True).head(2)
# Out:
#     date_unemp unemp_rate
# 0  Dec 1, 2018      3.90%
# 1  Nov 1, 2018      3.70%

# %%
# Change types
unemp_clean.date_unemp = pd.to_datetime(unemp_clean.date_unemp)

# %%
# unemp_clean['unemp_rate'] = unemp_clean['unemp_rate'].str.rstrip('%').astype('float')
