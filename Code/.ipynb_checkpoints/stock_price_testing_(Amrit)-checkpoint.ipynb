# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
from matplotlib.patches import Patch

# %%
## csv of s&p 500 data from yahoo finance
filepath = "../Input/^GSPC.csv"

# Load spreadsheet
xl = pd.ExcelFile("../Input/government_shutdown_stats.xlsx")

# Load a sheet into a DataFrame by name:
shutdown_df = xl.parse(xl.sheet_names[0])

# %%
## read stock csv
stock_prices_unclean = pd.read_csv(filepath)

# %%
# ## make the index the date to help with cleaning
stock_prices_unclean = stock_prices_unclean.set_index(['Date'])

# %%
stock_prices_unclean.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1976-07-12  104.980003  106.300003  104.739998  105.900002  105.900002
# 1976-07-13  105.900002  106.779999  105.150002  105.669998  105.669998
# 1976-07-14  105.669998  106.610001  105.050003  105.949997  105.949997
# 1976-07-15  105.949997  106.250000  104.760002  105.199997  105.199997
# 1976-07-16  105.199997  105.269997  103.870003  104.680000  104.680000
#
#               Volume
# Date
# 1976-07-12  23750000
# 1976-07-13  27550000
# 1976-07-14  23840000
# 1976-07-15  20400000
# 1976-07-16  20450000

# %%
shutdown_df
# Out:
#     shutdown_number   from_date     to_date  length_in_days  \
# 0                 1  1976-09-30  1976-10-11              12
# 1                 2  1977-09-30  1977-10-13              14
# 2                 3  1977-10-31  1977-11-09              10
# 3                 4  1977-11-30  1977-12-09              10
# 4                 5  1978-09-30  1978-10-18              19
# 5                 6  1979-09-30  1979-10-12              13
# 6                 7  1981-11-20  1981-11-23               4
# 7                 8  1982-09-30  1982-10-02               3
# 8                 9  1982-12-17  1982-12-21               5
# 9                10  1983-11-10  1983-11-14               5
# 10               11  1984-09-30  1984-10-03               4
# 11               12  1984-10-03  1984-10-05               3
# 12               13  1986-10-16  1986-10-18               3
# 13               14  1987-12-18  1987-12-20               3
# 14               15  1990-10-05  1990-10-09               5
# 15               16  1995-11-13  1995-11-19               7
# 16               17  1995-12-05  1996-01-06              33
# 17               18  2013-10-01  2013-10-17              17
# 18               19  2018-01-20  2018-01-22               3
# 19               20  2018-02-09  2018-02-09               1
#
#    pres_party_in_power      president senate_party_in_power senate_seats  \
# 0                    R           Ford                     D      62 - 38
# 1                    D         Carter                     D      59 - 41
# 2                    D         Carter                     D      59 - 41
# 3                    D         Carter                     D      59 - 41
# 4                    D         Carter                     D      59 - 41
# 5                    D         Carter                     D      58 - 42
# 6                    R         Reagan                     R      53 - 47
# 7                    R         Reagan                     R      53 - 47
# 8                    R         Reagan                     R      53 - 47
# 9                    R         Reagan                     R      55 - 45
# 10                   R         Reagan                     R      55 - 45
# 11                   R         Reagan                     R      55 - 45
# 12                   R         Reagan                     R      53 - 47
# 13                   R         Reagan                     D      54 - 46
# 14                   R  G. H. W. Bush                     D      55 - 45
# 15                   D        Clinton                     R      53 - 47
# 16                   D        Clinton                     R      53 - 47
# 17                   D          Obama                     D      54 - 46
# 18                   R          Trump                     R      51 - 49
# 19                   R          Trump                     R      51 - 49
#
#    house_party_in_power house_seats
# 0                     D   291 - 144
# 1                     D   292 - 143
# 2                     D   292 - 143
# 3                     D   292 - 143
# 4                     D   292 - 143
# 5                     D   277 - 158
# 6                     D   244 - 191
# 7                     D   244 - 191
# 8                     D   244 - 191
# 9                     D   271 - 164
# 10                    D   270 - 165
# 11                    D   270 - 165
# 12                    D   253 - 182
# 13                    D   258 - 177
# 14                    D   258 - 176
# 15                    R   233 - 199
# 16                    R   235 - 198
# 17                    R   232 - 200
# 18                    R   238 - 193
# 19                    R   238 - 193

# %%
## loops through all of csv, only keeping date ranges we need
stock_prices_clean = pd.DataFrame()
obs_count_list = []
for shutdown in range(len(shutdown_df)):
    try: 
        from_date = stock_prices_unclean.index.get_loc(shutdown_df["from_date"][shutdown])
    except KeyError: 
        from_date = stock_prices_unclean.index.get_loc(str((pd.to_datetime(shutdown_df["from_date"][shutdown]) + datetime.timedelta(days=2)).date()))

    try: 
        to_date = stock_prices_unclean.index.get_loc(shutdown_df["to_date"][shutdown])
    except KeyError: 
        to_date = stock_prices_unclean.index.get_loc(str((pd.to_datetime(shutdown_df["to_date"][shutdown]) + datetime.timedelta(days=2)).date()))
        
    obs_count_list.append(len(stock_prices_unclean.iloc[from_date-3:to_date+3]))
    stock_prices_clean = stock_prices_clean.append(stock_prices_unclean.iloc[from_date-3:to_date+3])

# %%
obs_count_list
# Out:
# [13, 15, 13, 13, 18, 14, 7, 8, 8, 8, 7, 8, 8, 8, 8, 12, 28, 18, 6, 6]

# %%
## add shutdown number to the table
stock_prices_clean["Shutdown Number"] = 0
shutdown = 1
beg = 0
for x in obs_count_list:
    stock_prices_clean["Shutdown Number"].iloc[beg:(beg+x)] = shutdown
    shutdown += 1
    beg = (beg + x)
# Out:
# C:\Users\Amrit\Anaconda3\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
stock_prices_clean
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 1976-09-27   106.800003   107.699997   106.349998   107.269997   107.269997
# 1976-09-28   107.269997   107.540001   105.610001   105.919998   105.919998
# 1976-09-29   105.919998   106.449997   104.830002   105.370003   105.370003
# 1976-09-30   105.370003   105.839996   104.570000   105.239998   105.239998
# 1976-10-01   105.239998   105.750000   103.599998   104.169998   104.169998
# 1976-10-04   104.169998   104.620003   103.419998   104.029999   104.029999
# 1976-10-05   104.029999   104.250000   102.510002   103.230003   103.230003
# 1976-10-06   103.230003   103.720001   102.050003   102.970001   102.970001
# 1976-10-07   102.970001   103.900002   102.160004   103.540001   103.540001
# 1976-10-08   103.540001   104.000000   102.239998   102.559998   102.559998
# 1976-10-11   102.480003   102.480003   100.980003   101.639999   101.639999
# 1976-10-12   101.639999   102.190002   100.379997   100.809998   100.809998
# 1976-10-13   100.809998   102.440002   100.540001   102.120003   102.120003
# 1977-09-27    95.379997    96.010002    94.760002    95.239998    95.239998
# 1977-09-28    95.239998    95.910004    94.730003    95.309998    95.309998
# 1977-09-29    95.309998    96.279999    95.089996    95.849998    95.849998
# 1977-09-30    95.849998    96.849998    95.660004    96.529999    96.529999
# 1977-10-03    96.529999    97.110001    95.860001    96.739998    96.739998
# 1977-10-04    96.739998    97.269997    95.730003    96.029999    96.029999
# 1977-10-05    96.029999    96.360001    95.199997    95.680000    95.680000
# 1977-10-06    95.680000    96.449997    95.300003    96.050003    96.050003
# 1977-10-07    96.050003    96.510002    95.480003    95.970001    95.970001
# 1977-10-10    95.970001    96.150002    95.320000    95.750000    95.750000
# 1977-10-11    95.750000    95.970001    94.730003    94.930000    94.930000
# 1977-10-12    94.820000    94.820000    93.400002    94.040001    94.040001
# 1977-10-11    17870000                2
# 1977-10-12    22440000                2
# 1977-10-13    23870000                2
# 1977-10-14    20410000                2
# 1977-10-17    17340000                2
# 1977-10-26    24860000                3
# 1977-10-27    21920000                3
# ...                ...              ...
# 2013-09-26  2813930000               18
# 2013-09-27  2951700000               18
# 2013-09-30  3308630000               18
# 2013-10-01  3238690000               18
# 2013-10-02  3148600000               18
# 2013-10-03  3279650000               18
# 2013-10-04  2880270000               18
# 2013-10-07  2678490000               18
# 2013-10-08  3569230000               18
# 2013-10-09  3577840000               18
# 2013-10-10  3362300000               18
# 2013-10-11  2944670000               18
# 2013-10-14  2580580000               18
# 2013-10-15  3327740000               18
# 2013-10-16  3486180000               18
# 2013-10-17  3453590000               18
# 2013-10-18  3664890000               18
# 2013-10-21  3052710000               18
# 2018-01-17  3778050000               19
# 2018-01-18  3681470000               19
# 2018-01-19  3639430000               19
# 2018-01-22  3471780000               19
# 2018-01-23  3519650000               19
# 2018-01-24  4014070000               19
# 2018-02-06  5891660000               20
# 2018-02-07  4626570000               20
# 2018-02-08  5305440000               20
# 2018-02-09  5680070000               20
# 2018-02-12  4055790000               20
# 2018-02-13  3472870000               20
#
# [226 rows x 7 columns]

# %%
grouped_shutdown_prices = stock_prices_clean.groupby("Shutdown Number")

# %%
(grouped_shutdown_prices.max()-grouped_shutdown_prices.min())/grouped_shutdown_prices.mean()
# Out:
#                      Open      High       Low     Close  Adj Close    Volume
# Shutdown Number
# 1                0.062048  0.052635  0.057951  0.062260   0.062260  0.501042
# 2                0.034396  0.033792  0.031587  0.034439   0.034439  0.698910
# 3                0.047659  0.057086  0.055574  0.056987   0.056987  0.819171
# 4                0.041396  0.039166  0.039605  0.041489   0.041489  0.302203
# 5                0.059595  0.067305  0.071654  0.072499   0.072499  0.921383
# 6                0.073221  0.071598  0.073624  0.075082   0.075082  1.371429
# 7                0.026955  0.029542  0.030283  0.031102   0.031102  0.306645
# 8                0.026346  0.035320  0.025276  0.045290   0.045290  0.749851
# 9                0.034717  0.048427  0.029662  0.032616   0.032616  0.469992
# 10               0.029496  0.032902  0.028327  0.029293   0.029293  0.303325
# 11               0.027432  0.023987  0.025199  0.027530   0.027530  0.225419
# 12               0.029464  0.026059  0.025453  0.027133   0.027133  0.596769
# 13               0.017470  0.017951  0.018784  0.017548   0.017548  0.876560
# 14               0.044249  0.031068  0.042175  0.041656   0.041656  0.867945
# 15               0.047716  0.058356  0.066702  0.064091   0.064091  0.584337
# 16               0.023420  0.015087  0.020375  0.018388   0.018388  0.889855
# 17               0.026554  0.026553  0.036412  0.037785   0.037785  1.293235
# 18               0.052048  0.050099  0.055831  0.052535   0.052535  0.340504
# 19               0.021480  0.016685  0.018610  0.014574   0.014574  0.147198
# 20               0.033701  0.033180  0.056997  0.043082   0.043082  0.499881

# %%
## coefficient of variation
co_var = grouped_shutdown_prices.std()/grouped_shutdown_prices.mean()
presidents = shutdown_df["president"]

# %%
colors = []
for x in shutdown_df["pres_party_in_power"]:
    if x == "R":
        colors.append("r")
    elif x == "D":
        colors.append("b")
graph1 = co_var["Close"].plot(kind="bar",figsize=(10, 5), color= colors)
plt.ylabel("Volatility")
plt.xlabel("Shutdowns")
plt.title("Volatility of S&P 500 Across the Last 20 Government Shutdowns(During)")
plt.xticks(np.arange(20), presidents, rotation=55)
plt.show()

# %%
shutdown_df.head()
# Out:
#    shutdown_number   from_date     to_date  length_in_days  \
# 0                1  1976-09-30  1976-10-11              12
# 1                2  1977-09-30  1977-10-13              14
# 2                3  1977-10-31  1977-11-09              10
# 3                4  1977-11-30  1977-12-09              10
# 4                5  1978-09-30  1978-10-18              19
#
#   pres_party_in_power president senate_party_in_power senate_seats  \
# 0                   R      Ford                     D      62 - 38
# 1                   D    Carter                     D      59 - 41
# 2                   D    Carter                     D      59 - 41
# 3                   D    Carter                     D      59 - 41
# 4                   D    Carter                     D      59 - 41
#
#   house_party_in_power house_seats
# 0                    D   291 - 144
# 1                    D   292 - 143
# 2                    D   292 - 143
# 3                    D   292 - 143
# 4                    D   292 - 143

# %%
## loops through all of csv, only keeping date ranges we need
stock_prices_clean_month_before = pd.DataFrame()
obs_count_list_month = []
for shutdown in range(len(shutdown_df)):
    try: 
        from_date = stock_prices_unclean.index.get_loc(shutdown_df["from_date"][shutdown])
    except KeyError: 
        from_date = stock_prices_unclean.index.get_loc(str((pd.to_datetime(shutdown_df["from_date"][shutdown]) + datetime.timedelta(days=2)).date()))

    try: 
        to_date = stock_prices_unclean.index.get_loc(shutdown_df["to_date"][shutdown])
    except KeyError: 
        to_date = stock_prices_unclean.index.get_loc(str((pd.to_datetime(shutdown_df["to_date"][shutdown]) + datetime.timedelta(days=2)).date()))
        
    obs_count_list_month.append(len(stock_prices_unclean.iloc[from_date-30:to_date-24]))
    stock_prices_clean_month_before = stock_prices_clean_month_before.append(stock_prices_unclean.iloc[from_date-30:to_date-24])

# %%
stock_prices_clean_month_before
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 1976-08-18   104.800003   105.410004   104.120003   104.559998   104.559998
# 1976-08-19   104.559998   104.739998   103.010002   103.389999   103.389999
# 1976-08-20   103.309998   103.309998   101.959999   102.370003   102.370003
# 1976-08-23   102.370003   102.489998   101.040001   101.959999   101.959999
# 1976-08-24   101.959999   102.650002   100.980003   101.269997   101.269997
# 1976-08-25   101.269997   102.410004   100.430000   102.029999   102.029999
# 1976-08-26   102.029999   102.589996   101.010002   101.320000   101.320000
# 1976-08-27   101.320000   101.900002   100.550003   101.480003   101.480003
# 1976-08-30   101.480003   102.510002   101.220001   102.070000   102.070000
# 1976-08-31   102.070000   103.379997   101.940002   102.910004   102.910004
# 1976-09-01   102.910004   104.300003   102.599998   104.059998   104.059998
# 1976-09-02   104.059998   104.839996   103.470001   103.919998   103.919998
# 1976-09-03   103.919998   104.629997   103.360001   104.300003   104.300003
# 1977-08-18    97.739998    98.690002    97.209999    97.680000    97.680000
# 1977-08-19    97.680000    98.290001    96.779999    97.510002    97.510002
# 1977-08-22    97.510002    98.290001    96.839996    97.790001    97.790001
# 1977-08-23    97.790001    98.519997    97.180000    97.620003    97.620003
# 1977-08-24    97.620003    97.989998    96.769997    97.230003    97.230003
# 1977-08-25    97.180000    97.180000    95.809998    96.150002    96.150002
# 1977-08-26    96.150002    96.419998    95.040001    96.059998    96.059998
# 2018-01-04  2719.310059  2729.290039  2719.070068  2723.989990  2723.989990
#
#                 Volume  Shutdown Number
# Date
# 1976-08-18    17150000                1
# 1976-08-19    17230000                1
# 1976-08-20    14920000                1
# 1976-08-23    15450000                1
# 1976-08-24    16740000                1
# 1976-08-25    17400000                1
# 1976-08-26    15270000                1
# 1976-08-27    12120000                1
# 1976-08-30    11140000                1
# 1976-08-31    15480000                1
# 1976-09-01    18640000                1
# 1976-09-02    18920000                1
# 1976-09-03    13280000                1
# 1977-08-18    21040000                2
# 1977-08-19    20800000                2
# 1977-08-22    17870000                2
# 1977-08-23    20290000                2
# 1977-08-24    18170000                2
# 1977-08-25    19400000                2
# 1977-08-26    18480000                2
# 1977-08-29    15280000                2
# 1977-08-30    18220000                2
# 1977-08-31    19080000                2
# 1977-09-01    18820000                2
# 1977-09-02    15620000                2
# 1977-09-06    16130000                2
# 1977-09-07    18070000                2
# 1977-09-08    18290000                2
# 1977-09-19    16890000                3
# 1977-09-20    19030000                3
# ...                ...              ...
# 2013-08-19  2904530000               18
# 2013-08-20  2994090000               18
# 2013-08-21  2932180000               18
# 2013-08-22  2537460000               18
# 2013-08-23  2582670000               18
# 2013-08-26  2430670000               18
# 2013-08-27  3219190000               18
# 2013-08-28  2784010000               18
# 2013-08-29  2527550000               18
# 2013-08-30  2734300000               18
# 2013-09-03  3731610000               18
# 2013-09-04  3312150000               18
# 2013-09-05  2957110000               18
# 2013-09-06  3123880000               18
# 2013-09-09  3102780000               18
# 2013-09-10  3691800000               18
# 2013-09-11  3135460000               18
# 2013-09-12  3106290000               18
# 2017-12-06  3229000000               19
# 2017-12-07  3292400000               19
# 2017-12-08  3106150000               19
# 2017-12-11  3091950000               19
# 2017-12-12  3555680000               19
# 2017-12-13  3542370000               19
# 2017-12-27  2202080000               20
# 2017-12-28  2153330000               20
# 2017-12-29  2443490000               20
# 2018-01-02  3367250000               20
# 2018-01-03  3538660000               20
# 2018-01-04  3695260000               20
#
# [226 rows x 7 columns]

# %%
grouped_shutdown_prices_month = stock_prices_clean_month_before.groupby("Shutdown Number")

# %%
## coefficient of variation
co_var2 = grouped_shutdown_prices_month.std()/grouped_shutdown_prices_month.mean()

# %%
len(co_var2)
# Out:
# 20

# %%
colorsz = []
for x in shutdown_df["pres_party_in_power"]:
    if x == "R":
        colorsz.append("k")
    elif x == "D":
        colorsz.append("k")
graph2 = co_var2["Close"].plot(kind="bar",figsize=(10, 5), color=colorsz)
plt.ylabel("Volatility")
plt.xlabel("Month Before Shutdown")
plt.title("Volatility of S&P 500 Across the Last 20 Government Shutdowns(Month Before)")
plt.xticks(np.arange(20), presidents, rotation=55)
plt.show()

# %%
y = []
for x in range(len(co_var2)):
    y.append(x+.25)

# %%
ax = plt.subplots()

# co_var2["Close"].plot(kind="bar",figsize=(10, 5), color= colorsz)
plt.bar(y, co_var2['Close'], color = colorsz, width = 0.5)

co_var["Close"].plot(kind="bar",figsize=(10, 5), color= colors)
plt.ylabel("Volatility")
plt.xlabel("Shutdowns")
plt.title("Volatility of S&P 500 Across the Last 20 Government Shutdowns")
plt.xticks(np.arange(20), presidents, rotation=55)

legend_elements = [Patch(facecolor='k', label='1 Month Prior'), 
                   Patch(facecolor='r', label='Dem'), 
                   Patch(facecolor='b', label='Rep')]

plt.legend(handles =legend_elements)
plt.show()
