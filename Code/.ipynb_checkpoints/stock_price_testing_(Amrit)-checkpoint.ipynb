# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %%
## csv of s&p 500 data from yahoo finance
filepath = "../Input/^GSPC.csv"

# Load spreadsheet
xl = pd.ExcelFile("../Input/government_shutdown_stats.xlsx")

# Load a sheet into a DataFrame by name:
shutdown_df = xl.parse(xl.sheet_names[0])

# %%
## read stock csv
stock_prices_unclean = pd.read_csv(filepath)

# %%
# ## make the index the date to help with cleaning
stock_prices_unclean = stock_prices_unclean.set_index(['Date'])

# %%
shutdown_df
# Out:
#     shutdown_number   from_date     to_date  length_in_days  \
# 0                 1  1976-09-30  1976-10-11              12
# 1                 2  1977-09-30  1977-10-13              14
# 2                 3  1977-10-31  1977-11-09              10
# 3                 4  1977-11-30  1977-12-09              10
# 4                 5  1978-09-30  1978-10-18              19
# 5                 6  1979-09-30  1979-10-12              13
# 6                 7  1981-11-20  1981-11-23               4
# 7                 8  1982-09-30  1982-10-02               3
# 8                 9  1982-12-17  1982-12-21               5
# 9                10  1983-11-10  1983-11-14               5
# 10               11  1984-09-30  1984-10-03               4
# 11               12  1984-10-03  1984-10-05               3
# 12               13  1986-10-16  1986-10-18               3
# 13               14  1987-12-18  1987-12-20               3
# 14               15  1990-10-05  1990-10-09               5
# ...

# %%
stock_prices_unclean
# Out:
#              Date         Open         High          Low        Close  \
# 0      1976-09-15   103.940002   104.699997   103.279999   104.250000
# 1      1976-09-16   104.250000   105.589996   103.839996   105.339996
# 2      1976-09-17   105.339996   106.809998   105.139999   106.269997
# 3      1976-09-20   106.269997   107.199997   105.739998   106.320000
# 4      1976-09-21   106.320000   108.129997   106.089996   107.830002
# 5      1976-09-22   107.830002   108.720001   106.919998   107.459999
# 6      1976-09-23   107.459999   107.959999   106.400002   106.919998
# 7      1976-09-24   106.919998   107.360001   106.029999   106.800003
# 8      1976-09-27   106.800003   107.699997   106.349998   107.269997
# 9      1976-09-28   107.269997   107.540001   105.610001   105.919998
# 10     1976-09-29   105.919998   106.449997   104.830002   105.370003
# 11     1976-09-30   105.370003   105.839996   104.570000   105.239998
# ...

# %%
sum(shutdown_df["length_in_days"])
# Out:
# 174

# %%
# ## loops through all of csv, only keeping date ranges we need
# stock_prices_clean = pd.DataFrame()
# for shutdown in range(len(shutdown_df)):
#     stock_prices_clean = stock_prices_clean.append(stock_prices_unclean.loc[shutdown_df['from_date'][shutdown]:shutdown_df['to_date'][shutdown]])

# %%
# ## loops through all of csv, only keeping date ranges we need
# stock_prices_clean = pd.DataFrame()
# for shutdown in range(len(shutdown_df)):
#     try: 
#         from_date = stock_prices_unclean.index.get_loc(shutdown_df["from_date"][shutdown])
# #         to_date = stock_prices_unclean.index.get_loc(shutdown_df["to_date"][shutdown])
# #         stock_prices_clean = stock_prices_clean.append(stock_prices_unclean.iloc[from_date])
#     except KeyError: 
#         print(from_date)
# #         print(to_date)
#         from_date = stock_prices_unclean.index.get_loc(str((pd.to_datetime(shutdown_df["from_date"][shutdown]) + datetime.timedelta(days=3)).date()))
# #         to_date = stock_prices_unclean.index.get_loc(str((pd.to_datetime(shutdown_df["to_date"][shutdown]) + datetime.timedelta(days=5)).date()))
        
# #         stock_prices_clean = stock_prices_clean.append(stock_prices_unclean.iloc[from_date])

# %%
## loops through all of csv, only keeping date ranges we need
stock_prices_clean = pd.DataFrame()
for shutdown in range(len(shutdown_df)):
    try: 
        from_date = stock_prices_unclean.index.get_loc(shutdown_df["from_date"][shutdown])
    except KeyError: 
        from_date = stock_prices_unclean.index.get_loc(str((pd.to_datetime(shutdown_df["from_date"][shutdown]) + datetime.timedelta(days=2)).date()))

    try: 
        to_date = stock_prices_unclean.index.get_loc(shutdown_df["to_date"][shutdown])
    except KeyError: 
        to_date = stock_prices_unclean.index.get_loc(str((pd.to_datetime(shutdown_df["to_date"][shutdown]) + datetime.timedelta(days=2)).date()))

    
    stock_prices_clean = stock_prices_clean.append(stock_prices_unclean.iloc[from_date:to_date])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# KeyError: '1976-09-30'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
stock_prices_clean
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
stock_prices_unclean.index.get_loc("1995-11-18")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '1995-11-18'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-263-a1a6bc4b4642> in <module>()
# ...

# %%
# ## gets 5 obs before date of shutdown
# stock_prices_unclean.index.get_loc(shutdown_df["from_date"][0])-5
# ## gets 5 obs after date of shutdown
# stock_prices_unclean.index.get_loc(shutdown_df["to_date"][0])+5
str((pd.to_datetime(shutdown_df["from_date"][0]) + datetime.timedelta(days=3)).date())

# %%
## loops through all of csv, only keeping date ranges we need
stock_prices_clean = pd.DataFrame()
for shutdown in range(len(shutdown_df)):
    try: 
        
        stock_prices_clean = stock_prices_clean.append(stock_prices_unclean.iloc[(stock_prices_unclean.index.get_loc(shutdown_df["from_date"][shutdown]))])
    except KeyError: 
        stock_prices_clean = stock_prices_clean.append(stock_prices_unclean.iloc[(stock_prices_unclean.index.get_loc(str((pd.to_datetime(shutdown_df["from_date"][shutdown]) + datetime.timedelta(days=5)).date())))])

# %%
stock_prices_clean
# Out:
#               Adj Close        Close         High          Low         Open  \
# 1976-09-30   105.239998   105.239998   105.839996   104.570000   105.370003
# 1977-09-30    96.529999    96.529999    96.849998    95.660004    95.849998
# 1977-10-31    92.339996    92.339996    93.029999    91.849998    92.610001
# 1977-11-30    94.830002    94.830002    95.169998    93.779999    94.550003
# 1978-10-05   103.269997   103.269997   104.099998   102.540001   103.059998
# 1979-10-05   111.269997   111.269997   112.160004   110.160004   110.169998
# 1981-11-20   121.709999   121.709999   122.589996   120.129997   120.709999
# 1982-09-30   120.419998   120.419998   121.620003   120.139999   121.620003
# 1982-12-17   137.490005   137.490005   137.710007   135.350006   135.350006
# 1983-11-10   164.410004   164.410004   164.710007   163.970001   163.990005
# 1984-10-05   162.679993   162.679993   163.320007   162.509995   162.919998
# ...

# %%
# idx = (data2['buy'] == True).fillna(False)
# idx |= idx.shift(-1) | idx.shift(-2)   # one & two days after
# idx |= idx.shift(1) | idx.shift(2)     # one & two days before
# data2[ idx ] # this is what you need

# %%
type(shutdown_df['from_date'][1])

# %%
# df = pd.DataFrame(np.random.random((200,3)))
# df['date'] = pd.date_range('2000-1-1', periods=200, freq='D')
# df = df.set_index(['date'])
# print(df.loc['2000-6-1':'2000-6-10'])

# %%
+ datetime.timedelta(days=3)
