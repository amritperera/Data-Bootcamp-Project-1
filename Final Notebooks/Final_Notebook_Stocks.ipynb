# %%
## import dependencies 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

# %% [markdown]
# ## Loading Data and Cleanup

# %%
## csv of s&p 500 data from yahoo finance
filepath = "../Input/^GSPC.csv"

# Load spreadsheet
xl = pd.ExcelFile("../Input/government_shutdown_stats.xlsx")

# Load a sheet into a DataFrame by name:
shutdown_df = xl.parse(xl.sheet_names[0])

# %%
## showing the data we have on shutdown
shutdown_df
# Out:
#     shutdown_number   from_date     to_date  length_in_days  \
# 0                 1  1976-09-30  1976-10-11              12
# 1                 2  1977-09-30  1977-10-13              14
# 2                 3  1977-10-31  1977-11-09              10
# 3                 4  1977-11-30  1977-12-09              10
# 4                 5  1978-09-30  1978-10-18              19
# 5                 6  1979-09-30  1979-10-12              13
# 6                 7  1981-11-20  1981-11-23               4
# 7                 8  1982-09-30  1982-10-02               3
# 8                 9  1982-12-17  1982-12-21               5
# 9                10  1983-11-10  1983-11-14               5
# 10               11  1984-09-30  1984-10-03               4
# 11               12  1984-10-03  1984-10-05               3
# 12               13  1986-10-16  1986-10-18               3
# 13               14  1987-12-18  1987-12-20               3
# 14               15  1990-10-05  1990-10-09               5
# 15               16  1995-11-13  1995-11-19               7
# 16               17  1995-12-05  1996-01-06              33
# 17               18  2013-10-01  2013-10-17              17
# 18               19  2018-01-20  2018-01-22               3
# 19               20  2018-02-09  2018-02-09               1
#
#    pres_party_in_power      president senate_party_in_power senate_seats  \
# 0                    R           Ford                     D      62 - 38
# 1                    D         Carter                     D      59 - 41
# 2                    D         Carter                     D      59 - 41
# 3                    D         Carter                     D      59 - 41
# 4                    D         Carter                     D      59 - 41
# 5                    D         Carter                     D      58 - 42
# 6                    R         Reagan                     R      53 - 47
# 7                    R         Reagan                     R      53 - 47
# 8                    R         Reagan                     R      53 - 47
# 9                    R         Reagan                     R      55 - 45
# 10                   R         Reagan                     R      55 - 45
# 11                   R         Reagan                     R      55 - 45
# 12                   R         Reagan                     R      53 - 47
# 13                   R         Reagan                     D      54 - 46
# 14                   R  G. H. W. Bush                     D      55 - 45
# 15                   D        Clinton                     R      53 - 47
# 16                   D        Clinton                     R      53 - 47
# 17                   D          Obama                     D      54 - 46
# 18                   R          Trump                     R      51 - 49
# 19                   R          Trump                     R      51 - 49
#
#    house_party_in_power house_seats
# 0                     D   291 - 144
# 1                     D   292 - 143
# 2                     D   292 - 143
# 3                     D   292 - 143
# 4                     D   292 - 143
# 5                     D   277 - 158
# 6                     D   244 - 191
# 7                     D   244 - 191
# 8                     D   244 - 191
# 9                     D   271 - 164
# 10                    D   270 - 165
# 11                    D   270 - 165
# 12                    D   253 - 182
# 13                    D   258 - 177
# 14                    D   258 - 176
# 15                    R   233 - 199
# 16                    R   235 - 198
# 17                    R   232 - 200
# 18                    R   238 - 193
# 19                    R   238 - 193

# %%
## read stock csv
stock_prices_unclean = pd.read_csv(filepath)

# %%
# ## make the index the date to help with cleaning
stock_prices_unclean = stock_prices_unclean.set_index(['Date'])

# %%
## loops through all of csv, only keeping date ranges we need
stock_prices_clean = pd.DataFrame()
obs_count_list = []
for shutdown in range(len(shutdown_df)):
    try: 
        from_date = stock_prices_unclean.index.get_loc(shutdown_df["from_date"][shutdown])
    except KeyError: 
        from_date = stock_prices_unclean.index.get_loc(str((pd.to_datetime(shutdown_df
# 2013-10-11  2944670000               18
# 2013-10-14  2580580000               18
# 2013-10-15  3327740000               18
# 2013-10-16  3486180000               18
# 2013-10-17  3453590000               18
# 2013-10-18  3664890000               18
# 2013-10-21  3052710000               18
# 2018-01-17  3778050000               19
# 2018-01-18  3681470000               19
# 2018-01-19  3639430000               19
# 2018-01-22  3471780000               19
# 2018-01-23  3519650000               19
# 2018-01-24  4014070000               19
# 2018-02-06  5891660000               20
# 2018-02-07  4626570000               20
# 2018-02-08  5305440000               20
# 2018-02-09  5680070000               20
# 2018-02-12  4055790000               20
# 2018-02-13  3472870000               20
#
# [226 rows x 7 columns]

# %%
grouped_shutdown_prices = stock_prices_clean.groupby("Shutdown Number")

# %%
## coefficient of variation
co_var = grouped_shutdown_prices.std()/grouped_shutdown_prices.mean()
presidents = shutdown_df["president"]

# %%
co_var
# Out:
#                      Open      High       Low     Close  Adj Close    Volume
# Shutdown Number
# 1                0.018686  0.017692  0.018546  0.017659   0.017659  0.153532
# 2                0.010474  0.010950  0.011535  0.011644   0.011644  0.163228
# 3                0.012549  0.015235  0.014305  0.015883   0.015883  0.250734
# 4                0.014020  0.012541  0.012530  0.012635   0.012635  0.100198
# 5                0.015586  0.017019  0.018557  0.019220   0.019220  0.235481
# 6                0.023798  0.024481  0.027744  0.026246   0.026246  0.336758
# 7                0.009349  0.011240  0.010860  0.011603   0.011603  0.102225
# 8                0.008951  0.011687  0.009509  0.013946   0.013946  0.213329
# 9                0.012487  0.014714  0.011418  0.012083   0.012083  0.151083
# 10               0.011707  0.012135  0.011252  0.011544   0.011544  0.108212
# 11               0.011287  0.010430  0.010214  0.010787   0.010787  0.085874
# 12               0.010943  0.009914  0.008884  0.008952   0.008952  0.181946
# 13               0.007351  0.007086  0.006672  0.007075   0.007075  0.259074
# 14               0.016381  0.010321  0.015712  0.015273   0.015273  0.244551
# 15               0.016716  0.018660  0.021982  0.022986   0.022986  0.184649
# 16               0.007250  0.006157  0.007052  0.006308   0.006308  0.239486
# 17               0.007991  0.007264  0.008594  0.009186   0.009186  0.255565
# 18               0.013337  0.013183  0.014660  0.015061   0.015061  0.100969
# 19               0.008038  0.007165  0.007070  0.006582   0.006582  0.053168
# 20               0.013687  0.011304  0.019612  0.015951   0.015951  0.197318

# %%
## loops through all of csv, only keeping date ranges we need
stock_prices_clean_delta = pd.DataFrame()
obs_count_list = []
for shutdown in range(len(shutdown_df)):
    try: 
        from_date = stock_prices_unclean.index.get_loc(shutdown_df["from_date"][shutdown])
    except KeyError: 
        from_date = stock_prices_unclean.index.get_loc(str((pd.to_datetime(shutdown_df["from_date"][shutdown]) + datetime.timedelta(days=2)).date()))

    try: 
        to_date = stock_prices_unclean.index.get_loc(shutdown_df["to_date"][shutdown])
    except KeyError: 
        to_date = stock_prices_unclean.index.get_loc(str((pd.to_datetime(shutdown_df["to_date"][shutdown]) + datetime.timedelta(days=2)).date()))
        
    stock_prices_clean_delta = stock_prices_clean_delta.append(stock_prices_unclean.iloc[from_date-3])
    stock_prices_clean_delta = stock_prices_clean_delta.append(stock_prices_unclean.iloc[to_date+3])

# %%
# 1977-11-25  1.791000e+07
# 1977-12-14  2.211000e+07
# 1978-09-27  2.837000e+07
# 1978-10-23  3.609000e+07
# 1979-09-27  3.311000e+07
# 1979-10-17  2.965000e+07
# 1981-11-17  4.319000e+07
# 1981-11-27  3.277000e+07
# 1982-09-27  4.484000e+07
# 1982-10-07  1.470700e+08
# 1982-12-14  9.838000e+07
# 1982-12-27  6.469000e+07
# 1983-11-07  6.940000e+07
# 1983-11-17  8.074000e+07
# 1984-09-27  8.888000e+07
# 1984-10-08  4.636000e+07
# 1984-09-28  7.895000e+07
# 1984-10-10  9.427000e+07
# 1986-10-13  5.499000e+07
# 1986-10-23  1.509000e+08
# 1987-12-15  2.149700e+08
# 1987-12-28  1.312200e+08
# 1990-10-02  1.883600e+08
# 1990-10-12  1.879400e+08
# 1995-11-08  3.597800e+08
# 1995-11-27  3.591300e+08
# 1995-11-30  4.400500e+08
# 1996-01-11  4.088000e+08
# 2013-09-26  2.813930e+09
# 2013-10-22  3.850840e+09
# 2018-01-17  3.778050e+09
# 2018-01-25  3.835150e+09
# 2018-02-06  5.891660e+09
# 2018-02-14  4.003740e+09

# %%
stock_prices_clean_delta['Open'][0]
# Out:
# 106.800003

# %%
merging_list = []
count = 0
for x in range(20):
    merging_list.append((stock_prices_clean_delta['Close'][count+1]-stock_prices_clean_delta['Open'][count])*100/stock_prices_clean_delta['Open'][count])
    count = count + 2

# %%
merging_list
# Out:
# [-5.571165573843667,
#  -2.0129985955021645,
#  4.74725274725274,
#  -2.54948600993856,
#  -4.326644777042143,
#  -5.974900017960161,
#  4.033597871483663,
#  4.443726078494981,
#  1.5572490336006461,
#  2.2842057909642497,
#  -2.7706116941529166,
#  -2.9048908700632765,
#  1.5964652412285252,
#  1.395600550017743,
#  -4.734236014896565,
#  2.5583298916831945,
#  -0.8146292011397778,
#  3.5784063780042574,
#  1.9483017962301532,
#  3.206765122497407]

# %%
final_test = co_var

# %%
final_test["Percent Change"] = merging_list

# %%
final_test.head()
# Out:
#                      Open      High       Low     Close  Adj Close    Volume  \
# Shutdown Number
# 1                0.018686  0.017692  0.018546  0.017659   0.017659  0.153532
# 2                0.010474  0.010950  0.011535  0.011644   0.011644  0.163228
# 3                0.012549  0.015235  0.014305  0.015883   0.015883  0.250734
# 4                0.014020  0.012541  0.012530  0.012635   0.012635  0.100198
# 5                0.015586  0.017019  0.018557  0.019220   0.019220  0.235481
#
#                  Percent Change
# Shutdown Number
# 1                     -5.571166
# 2                     -2.012999
# 3                      4.747253
# 4                     -2.549486
# 5                     -4.326645

# %%
list(shutdown_df['length_in_days'])
# Out:
# [12, 14, 10, 10, 19, 13, 4, 3, 5, 5, 4, 3, 3, 3, 5, 7, 33, 17, 3, 1]

# %%
final_test["Length"] = list(shutdown_df['length_in_days'])

# %% [markdown]
# ## Final Cleaned Table

# %%
final_test
# Out:
#                      Open      High       Low     Close  Adj Close    Volume  \
# Shutdown Number
# 1                0.018686  0.017692  0.018546  0.017659   0.017659  0.153532
# 2                0.010474  0.010950  0.011535  0.011644   0.011644  0.163228
# 3                0.012549  0.015235  0.014305  0.015883   0.015883  0.250734
# 4                0.014020  0.012541  0.012530  0.012635   0.012635  0.100198
# 5                0.015586  0.017019  0.018557  0.019220   0.019220  0.235481
# 6                0.023798  0.024481  0.027744  0.026246   0.026246  0.336758
# 7                0.009349  0.011240  0.010860  0.011603   0.011603  0.102225
# 8                0.008951  0.011687  0.009509  0.013946   0.013946  0.213329
# 9                0.012487  0.014714  0.011418  0.012083   0.012083  0.151083
# 10               0.011707  0.012135  0.011252  0.011544   0.011544  0.108212
# 11               0.011287  0.010430  0.010214  0.010787   0.010787  0.085874
# 12               0.010943  0.009914  0.008884  0.008952   0.008952  0.181946
# 13               0.007351  0.007086  0.006672  0.007075   0.007075  0.259074
# 14               0.016381  0.010321  0.015712  0.015273   0.015273  0.244551
# 15               0.016716  0.018660  0.021982  0.022986   0.022986  0.184649
# 16               0.007250  0.006157  0.007052  0.006308   0.006308  0.239486
# 17               0.007991  0.007264  0.008594  0.009186   0.009186  0.255565
# 18               0.013337  0.013183  0.014660  0.015061   0.015061  0.100969
# 19               0.008038  0.007165  0.007070  0.006582   0.006582  0.053168
# 20               0.013687  0.011304  0.019612  0.015951   0.015951  0.197318
#
#                  Percent Change  Length
# Shutdown Number
# 1                     -5.571166      12
# 2                     -2.012999      14
# 3                      4.747253      10
# 4                     -2.549486      10
# 5                     -4.326645      19
# 6                     -5.974900      13
# 7                      4.033598       4
# 8                      4.443726       3
# 9                      1.557249       5
# 10                     2.284206       5
# 11                    -2.770612       4
# 12                    -2.904891       3
# 13                     1.596465       3
# 14                     1.395601       3
# 15                    -4.734236       5
# 16                     2.558330       7
# 17                    -0.814629      33
# 18                     3.578406      17
# 19                     1.948302       3
# 20                     3.206765       1

# %%
colors = []
for x in shutdown_df["pres_party_in_power"]:
    if x == "R":
        colors.append("r")
    elif x == "D":
        colors.append("b")

# %% [markdown]
# ## Visualization

# %%
presidents = shutdown_df["president"]
y = []
for x in range(len(final_test)):
    y.append(x+0)
colors = []
for x in shutdown_df["pres_party_in_power"]:
    if x == "R":
        colors.append("r")
    elif x == "D":
        colors.append("b")
plt.bar(y,final_test['Percent Change'],color = colors, width = .8 )
plt.ylabel("Percent Change")
plt.xlabel("Shutdowns")
plt.title("Percent Change of S&P 500 Across the Last 20 Government Shutdowns")
plt.xticks(np.arange(20), presidents, rotation=65)
legend_elements = [Patch(facecolor='r', label='Rep'), 
                   Patch(facecolor='b', label='Dem')]

plt.legend(handles =legend_elements)
plt.rcParams["figure.figsize"] = [16,9]
plt.show()

# %%
plt.scatter(final_test['Close'],final_test['Percent Change'],
            s=final_test['Length']*7.5 ,c=colors, alpha=.8 , edgecolors='black' )
plt.xlabel('Volatility')
plt.ylabel('Percent Change')
plt.title('S&P 500 Volatility vs Percent Change during the Last 20 Shutdowns')
plt.xlim(0, .03)

legend_elements = [Line2D([0], [0], marker='o', color='k', label='Dem',
                          markerfacecolor='b', markersize=10),
                  Line2D([0], [0], marker='o', color='k', label='Rep',
                          markerfacecolor='r', markersize=10)]
plt.legend(handles = legend_elements)
plt.grid()
